# %%
#Importing the packages and reading the training data
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
df=pd.read_csv("Train.csv")

# %%
#Printing the first five tuples of the dataset
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
#Printing the summary of the Train dataset
df.info
# Out:
# <bound method DataFrame.info of         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
#Generating the descriptive statistics for the columns
df.describe
# Out:
# <bound method NDFrame.describe of         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
#Printing all the column headers in the Train dataset
df.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
#Printing all the rows and columns present inside the Train dataset
df.shape
# Out:
# (1460, 81)

# %%
#Checking if there is any null value present in the actual dataset
df.isnull().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %%
#Setting all the required data in Linear Regression and printing the first five tuples of it
d=df[['SalePrice','LotArea','BedroomAbvGr','BsmtFinSF1','BsmtFinSF2','MasVnrArea','BsmtUnfSF','TotalBsmtSF','LowQualFinSF','GrLivArea','BsmtFullBath','BsmtHalfBath','FullBath','HalfBath','BedroomAbvGr','GarageArea','PoolArea','WoodDeckSF','OpenPorchSF']]
d.head()
# Out:
#    SalePrice  LotArea  BedroomAbvGr  BsmtFinSF1  BsmtFinSF2  MasVnrArea  \
# 0     208500     8450             3         706           0       196.0
# 1     181500     9600             3         978           0         0.0
# 2     223500    11250             3         486           0       162.0
# 3     140000     9550             3         216           0         0.0
# 4     250000    14260             4         655           0       350.0
#
#    BsmtUnfSF  TotalBsmtSF  LowQualFinSF  GrLivArea  BsmtFullBath  \
# 0        150          856             0       1710             1
# 1        284         1262             0       1262             0
# 2        434          920             0       1786             1
# 3        540          756             0       1717             1
# 4        490         1145             0       2198             1
#
#    BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  GarageArea  PoolArea  \
# ...

# %%
#Printing all the rows and columns of the newly built dataset
d.shape
# Out:
# (1460, 19)

# %%
#Checking if there is any null value in the modified dataset
d.isnull().sum()
# Out:
# SalePrice       0
# LotArea         0
# BedroomAbvGr    0
# BsmtFinSF1      0
# BsmtFinSF2      0
# MasVnrArea      8
# BsmtUnfSF       0
# TotalBsmtSF     0
# LowQualFinSF    0
# GrLivArea       0
# BsmtFullBath    0
# BsmtHalfBath    0
# FullBath        0
# HalfBath        0
# BedroomAbvGr    0
# GarageArea      0
# PoolArea        0
# WoodDeckSF      0
# OpenPorchSF     0
# dtype: int64

# %%
#Discarding the rows having null values in any of the feature
d.dropna(inplace=True)
d.shape
# Out:
# C:\Users\RITAM SARKAR\AppData\Local\Temp\ipykernel_18852\4025182956.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   d.dropna(inplace=True)
# (1452, 19)

# %%
#Defining the values of x and y for training
x=d.drop('SalePrice',axis=1)
y=d['SalePrice']

# %%
#Fitting the training data into the Linear Regression model
lr=LinearRegression()
lr.fit(x,y)
# Out:
# LinearRegression()

# %%
d['SalePrice'].head()
# Out:
# 0    208500
# 1    181500
# 2    223500
# 3    140000
# 4    250000
# Name: SalePrice, dtype: int64

# %%
#Predicting the values of output variable
y_pred=lr.predict(d.iloc[:10,1:])
y_pred
# Out:
# array([214410.18313427, 181955.44156565, 223901.94370926, 171404.04726402,
#        277126.70150001, 183673.03023457, 250639.65008464, 257257.67227653,
#        197245.92347767, 126110.40040251])

# %%
#Printing the model accuracy for the training data
lr.score(x,y)
# Out:
# 0.7209761335632483

# %%
#Reading the Test dataset and printing the first five tuples of it
a=pd.read_csv("Test.csv")
a.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#   LandContour Utilities  ... ScreenPorch PoolArea PoolQC  Fence MiscFeature  \
# 0         Lvl    AllPub  ...         120        0    NaN  MnPrv         NaN
# 1         Lvl    AllPub  ...           0        0    NaN    NaN        Gar2
# 2         Lvl    AllPub  ...           0        0    NaN  MnPrv         NaN
# 3         Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# 4         HLS    AllPub  ...         144        0    NaN    NaN         NaN
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition
# ...

# %%
#Setting all the required data and printing the first five tuples of it
a1=a[['LotArea','BedroomAbvGr','BsmtFinSF1','BsmtFinSF2','MasVnrArea','BsmtUnfSF','TotalBsmtSF','LowQualFinSF','GrLivArea','BsmtFullBath','BsmtHalfBath','FullBath','HalfBath','BedroomAbvGr','GarageArea','PoolArea','WoodDeckSF','OpenPorchSF']]
a1.head()
# Out:
#    LotArea  BedroomAbvGr  BsmtFinSF1  BsmtFinSF2  MasVnrArea  BsmtUnfSF  \
# 0    11622             2       468.0       144.0         0.0      270.0
# 1    14267             3       923.0         0.0       108.0      406.0
# 2    13830             3       791.0         0.0         0.0      137.0
# 3     9978             3       602.0         0.0        20.0      324.0
# 4     5005             2       263.0         0.0         0.0     1017.0
#
#    TotalBsmtSF  LowQualFinSF  GrLivArea  BsmtFullBath  BsmtHalfBath  FullBath  \
# 0        882.0             0        896           0.0           0.0         1
# 1       1329.0             0       1329           0.0           0.0         1
# 2        928.0             0       1629           0.0           0.0         2
# 3        926.0             0       1604           0.0           0.0         2
# 4       1280.0             0       1280           0.0           0.0         2
#
# ...

# %%
#Printing the number of rows and columns present in the taken dataset
a1.shape
# Out:
# (1459, 18)

# %%
#Checking whether there is any null values in any of the features or not
a1.isnull().sum()
# Out:
# LotArea          0
# BedroomAbvGr     0
# BsmtFinSF1       1
# BsmtFinSF2       1
# MasVnrArea      15
# BsmtUnfSF        1
# TotalBsmtSF      1
# LowQualFinSF     0
# GrLivArea        0
# BsmtFullBath     2
# BsmtHalfBath     2
# FullBath         0
# HalfBath         0
# BedroomAbvGr     0
# GarageArea       1
# PoolArea         0
# WoodDeckSF       0
# OpenPorchSF      0
# dtype: int64

# %%
#Discarding the rows having null values in any of the feature
a1.dropna(inplace=True)
a1.shape
# Out:
# C:\Users\RITAM SARKAR\AppData\Local\Temp\ipykernel_18852\3354429922.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a1.dropna(inplace=True)
# (1441, 18)

# %%
#Predicting the output feature of the Test dataset
x=a1
y_predict=lr.predict(x)
y_predict
# Out:
# array([137995.57137445, 170858.3054503 , 196545.51233106, ...,
#        165220.75692563,  86629.16201518, 235057.76906601])
